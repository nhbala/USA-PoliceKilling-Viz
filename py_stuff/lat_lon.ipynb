# %%
import numpy
import csv
import pandas
from matplotlib import pyplot

# %%
shootings_data = pandas.read_csv("fatal_police_shootings_2015-19.csv")

shootings_data.head(5)
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
import pandas 
file_name = "fatal_police_shootings_2015-19.csv"
a = pandas.read_csv("fatal_police_shootings_2015-19.csv")
b = pandas.read_csv("us_cities.csv")
b = b.dropna(axis=1)
i = 0



for index,row in a.iterrows():
     for indexb,rowb in b.iterrows():
            if row.loc['state'] == rowb.loc['state_id'] and row.loc['city'] == rowb.loc['city'] :
                
                lat = rowb.loc['lat']
                lon = rowb.loc['lng']
                row['lat'] = lat
                row['lon'] = lon

                print(row)
                
                with open(file_name, 'a') as csvFile:
                    writer = csv.writer(csvFile)
                    writer.writerow(row)
# Out:
# id                                   3
# name                        Tim Elliot
# date                        2015-01-02
# manner_of_death                   shot
# armed                              gun
# age                                 53
# gender                               M
# race                                 A
# city                           Shelton
# state                               WA
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            47.2188
# lon                           -123.113
# Name: 0, dtype: object
# id                                        4
# name                       Lewis Lee Lembke
# date                             2015-01-02
# manner_of_death                        shot
# armed                                   gun
# age                                      47
# gender                                    M
# race                                      W
# city                                  Aloha
# state                                    OR
# signs_of_mental_illness               False
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                  45.492
# lon                                -122.873
# Name: 1, dtype: object
# id                                          5
# name                       John Paul Quintero
# date                               2015-01-03
# manner_of_death              shot and Tasered
# armed                                 unarmed
# age                                        23
# gender                                      M
# race                                        H
# city                                  Wichita
# state                                      KS
# signs_of_mental_illness                 False
# threat_level                            other
# flee                              Not fleeing
# body_camera                             False
# lat                                   37.6897
# lon                                  -97.3442
# Name: 2, dtype: object
# id                                       8
# name                       Matthew Hoffman
# date                            2015-01-04
# manner_of_death                       shot
# armed                           toy weapon
# age                                     32
# gender                                   M
# race                                     W
# city                         San Francisco
# state                                   CA
# signs_of_mental_illness               True
# threat_level                        attack
# flee                           Not fleeing
# body_camera                          False
# lat                                37.7562
# lon                               -122.443
# Name: 3, dtype: object
# id                                         9
# name                       Michael Rodriguez
# date                              2015-01-04
# manner_of_death                         shot
# armed                               nail gun
# age                                       39
# gender                                     M
# race                                       H
# city                                   Evans
# state                                     CO
# signs_of_mental_illness                False
# threat_level                          attack
# flee                             Not fleeing
# body_camera                            False
# lat                                   40.366
# lon                                 -104.739
# Name: 4, dtype: object
# id                                        11
# name                       Kenneth Joe Brown
# date                              2015-01-04
# manner_of_death                         shot
# armed                                    gun
# age                                       18
# gender                                     M
# race                                       W
# city                                 Guthrie
# state                                     OK
# signs_of_mental_illness                False
# threat_level                          attack
# flee                             Not fleeing
# body_camera                            False
# lat                                  35.8429
# lon                                 -97.4359
# Name: 5, dtype: object
# id                                          13
# name                       Kenneth Arnold Buck
# date                                2015-01-05
# manner_of_death                           shot
# armed                                      gun
# age                                         22
# gender                                       M
# race                                         H
# city                                  Chandler
# state                                       AZ
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                                       Car
# body_camera                              False
# lat                                    33.2827
# lon                                   -111.852
# Name: 6, dtype: object
# id                                    15
# name                       Brock Nichols
# date                          2015-01-06
# manner_of_death                     shot
# armed                                gun
# age                                   35
# gender                                 M
# race                                   W
# city                             Assaria
# state                                 KS
# signs_of_mental_illness            False
# threat_level                      attack
# flee                         Not fleeing
# body_camera                        False
# lat                              38.6802
# lon                              -97.604
# Name: 7, dtype: object
# id                                    16
# name                       Autumn Steele
# date                          2015-01-06
# manner_of_death                     shot
# armed                            unarmed
# age                                   34
# gender                                 F
# race                                   W
# city                          Burlington
# state                                 IA
# signs_of_mental_illness            False
# threat_level                       other
# flee                         Not fleeing
# body_camera                         True
# lat                              40.8072
# lon                             -91.1249
# Name: 8, dtype: object
# id                                      17
# name                       Leslie Sapp III
# date                            2015-01-06
# manner_of_death                       shot
# armed                           toy weapon
# age                                     47
# gender                                   M
# race                                     B
# city                             Knoxville
# state                                   PA
# signs_of_mental_illness              False
# threat_level                        attack
# flee                           Not fleeing
# body_camera                          False
# lat                                41.9605
# lon                               -77.4379
# Name: 9, dtype: object
# id                                       19
# name                         Patrick Wetter
# date                             2015-01-06
# manner_of_death            shot and Tasered
# armed                                 knife
# age                                      25
# gender                                    M
# race                                      W
# city                               Stockton
# state                                    CA
# signs_of_mental_illness               False
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 37.9766
# lon                                -121.311
# Name: 10, dtype: object
# id                                  21
# name                         Ron Sneed
# date                        2015-01-07
# manner_of_death                   shot
# armed                              gun
# age                                 31
# gender                               M
# race                                 B
# city                          Freeport
# state                               TX
# signs_of_mental_illness          False
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            28.9454
# lon                           -95.3601
# Name: 11, dtype: object
# id                                                     22
# name                       Hashim Hanif Ibn Abdul-Rasheed
# date                                           2015-01-07
# manner_of_death                                      shot
# armed                                               knife
# age                                                    41
# gender                                                  M
# race                                                    B
# city                                             Columbus
# state                                                  OH
# signs_of_mental_illness                              True
# threat_level                                        other
# flee                                          Not fleeing
# body_camera                                         False
# lat                                                39.986
# lon                                              -82.9852
# Name: 12, dtype: object
# id                                             25
# name                       Nicholas Ryan Brickman
# date                                   2015-01-07
# manner_of_death                              shot
# armed                                         gun
# age                                            30
# gender                                          M
# race                                            W
# city                                   Des Moines
# state                                          IA
# signs_of_mental_illness                     False
# threat_level                               attack
# flee                                          Car
# body_camera                                 False
# lat                                       41.5725
# lon                                      -93.6104
# Name: 13, dtype: object
# id                                                       27
# name                       Omarr Julian Maximillian Jackson
# date                                             2015-01-07
# manner_of_death                                        shot
# armed                                                   gun
# age                                                      37
# gender                                                    M
# race                                                      B
# city                                            New Orleans
# state                                                    LA
# signs_of_mental_illness                               False
# threat_level                                         attack
# flee                                                   Foot
# body_camera                                            True
# lat                                                 30.0687
# lon                                                -89.9288
# Name: 14, dtype: object
# id                                    29
# name                       Loren Simpson
# date                          2015-01-08
# manner_of_death                     shot
# armed                                NaN
# age                                   28
# gender                                 M
# race                                   W
# city                             Huntley
# state                                 MT
# signs_of_mental_illness            False
# threat_level                undetermined
# flee                         Not fleeing
# body_camera                        False
# lat                              45.8995
# lon                             -108.305
# Name: 15, dtype: object
# id                                          32
# name                       James Dudley Barker
# date                                2015-01-08
# manner_of_death                           shot
# armed                                   shovel
# age                                         42
# gender                                       M
# race                                         W
# city                            Salt Lake City
# state                                       UT
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                               Not fleeing
# body_camera                               True
# lat                                    40.7774
# lon                                    -111.93
# Name: 16, dtype: object
# id                                          36
# name                       Artago Damon Howard
# date                                2015-01-08
# manner_of_death                           shot
# armed                                  unarmed
# age                                         36
# gender                                       M
# race                                         B
# city                                    Strong
# state                                       AR
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                               Not fleeing
# body_camera                              False
# lat                                    33.1079
# lon                                   -92.3598
# Name: 17, dtype: object
# id                                   37
# name                       Thomas Hamby
# date                         2015-01-08
# manner_of_death                    shot
# armed                               gun
# age                                  49
# gender                                M
# race                                  W
# city                           Syracuse
# state                                UT
# signs_of_mental_illness           False
# threat_level                     attack
# flee                        Not fleeing
# body_camera                        True
# lat                             41.0863
# lon                             -112.07
# Name: 18, dtype: object
# id                                    38
# name                       Jimmy Foreman
# date                          2015-01-09
# manner_of_death                     shot
# armed                                gun
# age                                   71
# gender                                 M
# race                                   W
# city                             England
# state                                 AR
# signs_of_mental_illness            False
# threat_level                      attack
# flee                         Not fleeing
# body_camera                        False
# lat                              34.5459
# lon                              -91.969
# Name: 19, dtype: object
# id                                   325
# name                       Andy Martinez
# date                          2015-01-09
# manner_of_death                     shot
# armed                                gun
# age                                   33
# gender                                 M
# race                                   H
# city                             El Paso
# state                                 TX
# signs_of_mental_illness            False
# threat_level                      attack
# flee                         Not fleeing
# body_camera                        False
# lat                              31.8479
# lon                             -106.431
# Name: 20, dtype: object
# id                                  42
# name                       Tommy Smith
# date                        2015-01-11
# manner_of_death                   shot
# armed                              gun
# age                                 39
# gender                               M
# race                                 W
# city                            Arcola
# state                               IL
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            39.6834
# lon                           -88.3012
# Name: 21, dtype: object
# id                                     43
# name                       Brian  Barbosa
# date                           2015-01-11
# manner_of_death                      shot
# armed                                 gun
# age                                    23
# gender                                  M
# race                                    H
# city                           South Gate
# state                                  CA
# signs_of_mental_illness             False
# threat_level                       attack
# flee                          Not fleeing
# body_camera                         False
# lat                               33.9447
# lon                              -118.193
# Name: 22, dtype: object
# id                                        45
# name                       Salvador Figueroa
# date                              2015-01-11
# manner_of_death             shot and Tasered
# armed                                    gun
# age                                       29
# gender                                     M
# race                                       H
# city                         North Las Vegas
# state                                     NV
# signs_of_mental_illness                False
# threat_level                          attack
# flee                                    Foot
# body_camera                            False
# lat                                   36.288
# lon                                  -115.09
# Name: 23, dtype: object
# id                                          46
# name                       John Edward O'Keefe
# date                                2015-01-13
# manner_of_death                           shot
# armed                                      gun
# age                                         34
# gender                                       M
# race                                         W
# city                               Albuquerque
# state                                       NM
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                                      Foot
# body_camera                               True
# lat                                    35.1053
# lon                                   -106.646
# Name: 24, dtype: object
# id                                        48
# name                       Richard McClendon
# date                              2015-01-13
# manner_of_death                         shot
# armed                                  knife
# age                                       43
# gender                                     M
# race                                       W
# city                              Jourdanton
# state                                     TX
# signs_of_mental_illness                 True
# threat_level                           other
# flee                             Not fleeing
# body_camera                            False
# lat                                  28.9138
# lon                                 -98.5411
# Name: 25, dtype: object
# id                                   51
# name                       Mario Jordan
# date                         2015-01-14
# manner_of_death                    shot
# armed                               gun
# age                                  34
# gender                                M
# race                                  B
# city                         Chesapeake
# state                                VA
# signs_of_mental_illness            True
# threat_level                     attack
# flee                        Not fleeing
# body_camera                       False
# lat                             36.6778
# lon                            -76.3024
# Name: 28, dtype: object
# id                                       52
# name                       Talbot Schroeder
# date                             2015-01-14
# manner_of_death                        shot
# armed                                 knife
# age                                      75
# gender                                    M
# race                                      W
# city                             Old Bridge
# state                                    NJ
# signs_of_mental_illness               False
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 40.3946
# lon                                -74.3323
# Name: 29, dtype: object
# id                                     54
# name                       Robert Edwards
# date                           2015-01-14
# manner_of_death                      shot
# armed                                 gun
# age                                    68
# gender                                  M
# race                                    W
# city                         Lake Jackson
# state                                  TX
# signs_of_mental_illness             False
# threat_level                       attack
# flee                          Not fleeing
# body_camera                         False
# lat                               29.0516
# lon                              -95.4522
# Name: 30, dtype: object
# id                                         55
# name                       Jeffrey R. Nielson
# date                               2015-01-14
# manner_of_death                          shot
# armed                                   knife
# age                                        34
# gender                                      M
# race                                        W
# city                                   Draper
# state                                      UT
# signs_of_mental_illness                 False
# threat_level                           attack
# flee                              Not fleeing
# body_camera                              True
# lat                                   40.4956
# lon                                  -111.861
# Name: 31, dtype: object
# id                                   56
# name                       Donte Sowell
# date                         2015-01-15
# manner_of_death                    shot
# armed                               gun
# age                                  27
# gender                                M
# race                                  B
# city                       Indianapolis
# state                                IN
# signs_of_mental_illness           False
# threat_level                     attack
# flee                               Foot
# body_camera                       False
# lat                             39.7771
# lon                            -86.1458
# Name: 32, dtype: object
# id                                          57
# name                       Kavonda Earl Payton
# date                                2015-01-15
# manner_of_death                           shot
# armed                                      gun
# age                                         39
# gender                                       M
# race                                         B
# city                                    Aurora
# state                                       CO
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                               Not fleeing
# body_camera                              False
# lat                                    39.7084
# lon                                   -104.727
# Name: 33, dtype: object
# id                                         60
# name                       Quincy Reed Reindl
# date                               2015-01-15
# manner_of_death                          shot
# armed                                     gun
# age                                        24
# gender                                      M
# race                                        W
# city                              Bloomington
# state                                      MN
# signs_of_mental_illness                  True
# threat_level                           attack
# flee                              Not fleeing
# body_camera                             False
# lat                                   44.8306
# lon                                  -93.3151
# Name: 34, dtype: object
# id                                  63
# name                         Jose Ceja
# date                        2015-01-15
# manner_of_death                   shot
# armed                            knife
# age                                 36
# gender                               M
# race                                 H
# city                         Fairfield
# state                               CA
# signs_of_mental_illness           True
# threat_level                     other
# flee                       Not fleeing
# body_camera                      False
# lat                            38.2594
# lon                           -122.032
# Name: 35, dtype: object
# id                                 67
# name                       Scott Hall
# date                       2015-01-16
# manner_of_death                  shot
# armed                             gun
# age                                41
# gender                              M
# race                                W
# city                           Mabank
# state                              TX
# signs_of_mental_illness         False
# threat_level                   attack
# flee                              Car
# body_camera                     False
# lat                           32.3681
# lon                           -96.114
# Name: 37, dtype: object
# id                                       68
# name                          Zaki Shinwary
# date                             2015-01-16
# manner_of_death            shot and Tasered
# armed                                 knife
# age                                      48
# gender                                    M
# race                                      O
# city                                Fremont
# state                                    CA
# signs_of_mental_illness               False
# threat_level                          other
# flee                            Not fleeing
# body_camera                           False
# lat                                 37.5265
# lon                                -121.985
# Name: 38, dtype: object
# id                                     74
# name                       Terence Walker
# date                           2015-01-17
# manner_of_death                      shot
# armed                                 gun
# age                                    21
# gender                                  M
# race                                    B
# city                             Muskogee
# state                                  OK
# signs_of_mental_illness             False
# threat_level                       attack
# flee                                 Foot
# body_camera                          True
# lat                                35.743
# lon                              -95.3566
# Name: 39, dtype: object
# id                                  75
# name                        Pablo Meza
# date                        2015-01-17
# manner_of_death                   shot
# armed                              gun
# age                                 24
# gender                               M
# race                                 H
# city                       Los Angeles
# state                               CA
# signs_of_mental_illness          False
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            34.1139
# lon                           -118.407
# Name: 40, dtype: object
# id                                     78
# name                       Daniel Brumley
# date                           2015-01-17
# manner_of_death                      shot
# armed                               knife
# age                                    27
# gender                                  M
# race                                    H
# city                           Fort Worth
# state                                  TX
# signs_of_mental_illness             False
# threat_level                       attack
# flee                          Not fleeing
# body_camera                         False
# lat                               32.7814
# lon                              -97.3473
# Name: 41, dtype: object
# id                                        80
# name                       Jonathan Guillory
# date                              2015-01-18
# manner_of_death                         shot
# armed                                    gun
# age                                       32
# gender                                     M
# race                                       W
# city                                Maricopa
# state                                     AZ
# signs_of_mental_illness                 True
# threat_level                          attack
# flee                             Not fleeing
# body_camera                            False
# lat                                  33.0404
# lon                                 -112.001
# Name: 42, dtype: object
# id                                   85
# name                       Dewayne Carr
# date                         2015-01-20
# manner_of_death                    shot
# armed                               NaN
# age                                  42
# gender                                M
# race                                  B
# city                         Scottsdale
# state                                AZ
# signs_of_mental_illness           False
# threat_level                      other
# flee                                Car
# body_camera                       False
# lat                             33.6872
# lon                            -111.865
# Name: 45, dtype: object
# id                                       86
# name                       Todd Allen Hodge
# date                             2015-01-21
# manner_of_death                        shot
# armed                                   gun
# age                                      36
# gender                                    M
# race                                      W
# city                                  Hemet
# state                                    CA
# signs_of_mental_illness               False
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 33.7341
# lon                                -116.997
# Name: 46, dtype: object
# id                                  98
# name                       Andrew Toto
# date                        2015-01-21
# manner_of_death                   shot
# armed                              gun
# age                                 54
# gender                               M
# race                                 W
# city                             Derry
# state                               NH
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            42.8941
# lon                           -71.2848
# Name: 49, dtype: object
# id                                    99
# name                         Tiano Meton
# date                          2015-01-22
# manner_of_death                     shot
# armed                         toy weapon
# age                                   25
# gender                                 M
# race                                   B
# city                       Sierra Blanca
# state                                 TX
# signs_of_mental_illness            False
# threat_level                      attack
# flee                                 Car
# body_camera                        False
# lat                              31.1834
# lon                              -105.34
# Name: 50, dtype: object
# id                                        100
# name                       Kristiana Coignard
# date                               2015-01-22
# manner_of_death              shot and Tasered
# armed                                   knife
# age                                        17
# gender                                      F
# race                                        W
# city                                 Longview
# state                                      TX
# signs_of_mental_illness                  True
# threat_level                            other
# flee                              Not fleeing
# body_camera                             False
# lat                                   32.5192
# lon                                  -94.7622
# Name: 51, dtype: object
# id                                          336
# name                       Robert Francis Mesch
# date                                 2015-01-23
# manner_of_death                            shot
# armed                                       gun
# age                                          61
# gender                                        M
# race                                          W
# city                                     Austin
# state                                        TX
# signs_of_mental_illness                    True
# threat_level                             attack
# flee                                Not fleeing
# body_camera                               False
# lat                                     30.3006
# lon                                    -97.7517
# Name: 52, dtype: object
# id                                     101
# name                        Demaris Turner
# date                            2015-01-23
# manner_of_death                       shot
# armed                                  NaN
# age                                     29
# gender                                   M
# race                                     B
# city                       Fort Lauderdale
# state                                   FL
# signs_of_mental_illness              False
# threat_level                         other
# flee                           Not fleeing
# body_camera                          False
# lat                                26.1412
# lon                               -80.1464
# Name: 53, dtype: object
# id                                                102
# name                       Jose Antonio Espinoza Ruiz
# date                                       2015-01-23
# manner_of_death                                  shot
# armed                                           knife
# age                                                56
# gender                                              M
# race                                                H
# city                                        Levelland
# state                                              TX
# signs_of_mental_illness                         False
# threat_level                                    other
# flee                                      Not fleeing
# body_camera                                     False
# lat                                           33.5806
# lon                                          -102.364
# Name: 54, dtype: object
# id                                  341
# name                       Wendell King
# date                         2015-01-24
# manner_of_death                    shot
# armed                               gun
# age                                  40
# gender                                M
# race                                  W
# city                         Fort Worth
# state                                TX
# signs_of_mental_illness           False
# threat_level                     attack
# flee                        Not fleeing
# body_camera                       False
# lat                             32.7814
# lon                            -97.3473
# Name: 55, dtype: object
# id                                 105
# name                       Daryl Myler
# date                        2015-01-24
# manner_of_death                   shot
# armed                              gun
# age                                 45
# gender                               M
# race                                 W
# city                           Rexburg
# state                               ID
# signs_of_mental_illness          False
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                             43.822
# lon                           -111.793
# Name: 56, dtype: object
# id                                    107
# name                       Darin Hutchins
# date                           2015-01-24
# manner_of_death                      shot
# armed                               knife
# age                                    26
# gender                                  M
# race                                    B
# city                            Baltimore
# state                                  MD
# signs_of_mental_illness              True
# threat_level                        other
# flee                          Not fleeing
# body_camera                         False
# lat                               39.3051
# lon                              -76.6144
# Name: 57, dtype: object
# id                                        108
# name                       Orlando Jude Lopez
# date                               2015-01-25
# manner_of_death                          shot
# armed                                     gun
# age                                        26
# gender                                      M
# race                                        H
# city                                   Pueblo
# state                                      CO
# signs_of_mental_illness                 False
# threat_level                           attack
# flee                                      Car
# body_camera                             False
# lat                                   38.2701
# lon                                  -104.613
# Name: 58, dtype: object
# id                                      110
# name                       William Campbell
# date                             2015-01-25
# manner_of_death                        shot
# armed                                   gun
# age                                      59
# gender                                    M
# race                                    NaN
# city                                Winslow
# state                                    NJ
# signs_of_mental_illness               False
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 39.6573
# lon                                -74.8624
# Name: 59, dtype: object
# id                                       20
# name                       Jessie Hernandez
# date                             2015-01-26
# manner_of_death                        shot
# armed                                   NaN
# age                                      17
# gender                                    F
# race                                      H
# city                                 Denver
# state                                    CO
# signs_of_mental_illness               False
# threat_level                          other
# flee                            Not fleeing
# body_camera                           False
# lat                                 39.7621
# lon                                -104.876
# Name: 60, dtype: object
# id                                   324
# name                       Raymond Kmetz
# date                          2015-01-26
# manner_of_death                     shot
# armed                                gun
# age                                   68
# gender                                 M
# race                                   W
# city                            New Hope
# state                                 MN
# signs_of_mental_illness             True
# threat_level                      attack
# flee                         Not fleeing
# body_camera                        False
# lat                              45.0375
# lon                             -93.3869
# Name: 61, dtype: object
# id                                        352
# name                       Joshua Omar Garcia
# date                               2015-01-26
# manner_of_death                          shot
# armed                                 unarmed
# age                                        24
# gender                                      M
# race                                        H
# city                                   Tahoka
# state                                      TX
# signs_of_mental_illness                 False
# threat_level                            other
# flee                                      Car
# body_camera                             False
# lat                                    33.164
# lon                                  -101.795
# Name: 62, dtype: object
# id                                  353
# name                       David Garcia
# date                         2015-01-26
# manner_of_death                    shot
# armed                             knife
# age                                  34
# gender                                M
# race                                  H
# city                              Wasco
# state                                CA
# signs_of_mental_illness            True
# threat_level                      other
# flee                        Not fleeing
# body_camera                       False
# lat                             35.5938
# lon                            -119.367
# Name: 63, dtype: object
# id                                         348
# name                       Nicolas Leland Tewa
# date                                2015-01-27
# manner_of_death                           shot
# armed                                      NaN
# age                                         26
# gender                                       M
# race                                         N
# city                                   Phoenix
# state                                       AZ
# signs_of_mental_illness                  False
# threat_level                             other
# flee                               Not fleeing
# body_camera                              False
# lat                                    33.5722
# lon                                   -112.089
# Name: 64, dtype: object
# id                                  349
# name                       Chris Ingram
# date                         2015-01-27
# manner_of_death                    shot
# armed                               gun
# age                                  29
# gender                                M
# race                                  W
# city                            Morenci
# state                                AZ
# signs_of_mental_illness           False
# threat_level                     attack
# flee                        Not fleeing
# body_camera                       False
# lat                             33.0531
# lon                            -109.331
# Name: 65, dtype: object
# id                                       350
# name                       Jermonte Fletcher
# date                              2015-01-27
# manner_of_death                         shot
# armed                                    gun
# age                                       33
# gender                                     M
# race                                       B
# city                                Columbus
# state                                     OH
# signs_of_mental_illness                False
# threat_level                          attack
# flee                             Not fleeing
# body_camera                            False
# lat                                   39.986
# lon                                 -82.9852
# Name: 66, dtype: object
# id                                   111
# name                       Tiffany Terry
# date                          2015-01-27
# manner_of_death                     shot
# armed                              knife
# age                                   39
# gender                                 F
# race                                   W
# city                               Omaha
# state                                 NE
# signs_of_mental_illness             True
# threat_level                      attack
# flee                         Not fleeing
# body_camera                        False
# lat                              41.2628
# lon                             -96.0495
# Name: 67, dtype: object
# id                                         345
# name                       Alan Lance Alverson
# date                                2015-01-28
# manner_of_death                           shot
# armed                                      gun
# age                                         45
# gender                                       M
# race                                         W
# city                                    Sunset
# state                                       TX
# signs_of_mental_illness                  False
# threat_level                            attack
# flee                               Not fleeing
# body_camera                              False
# lat                                    33.4479
# lon                                   -97.7663
# Name: 68, dtype: object
# id                                      346
# name                            Matautu Nuu
# date                             2015-01-28
# manner_of_death            shot and Tasered
# armed                                hammer
# age                                      35
# gender                                    M
# race                                      A
# city                               Stockton
# state                                    CA
# signs_of_mental_illness                True
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 37.9766
# lon                                -121.311
# Name: 69, dtype: object
# id                                  347
# name                       Cody Karasek
# date                         2015-01-28
# manner_of_death                    shot
# armed                               gun
# age                                  26
# gender                                M
# race                                  W
# city                          Rosenberg
# state                                TX
# signs_of_mental_illness           False
# threat_level                     attack
# flee                        Not fleeing
# body_camera                       False
# lat                              29.544
# lon                            -95.8199
# Name: 70, dtype: object
# id                                  342
# name                       Ralph Willis
# date                         2015-01-29
# manner_of_death                    shot
# armed                           unarmed
# age                                  42
# gender                                M
# race                                  W
# city                         Stillwater
# state                                OK
# signs_of_mental_illness           False
# threat_level                      other
# flee                               Foot
# body_camera                       False
# lat                             36.1315
# lon                            -97.0739
# Name: 71, dtype: object
# id                                 112
# name                        Alan James
# date                        2015-01-29
# manner_of_death                   shot
# armed                              gun
# age                                 31
# gender                               M
# race                                 W
# city                           Wyoming
# state                               MI
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            42.8909
# lon                           -85.7066
# Name: 72, dtype: object
# id                                         113
# name                       John Barry Marshall
# date                                2015-01-30
# manner_of_death                           shot
# armed                                      gun
# age                                         48
# gender                                       M
# race                                         W
# city                                  Billings
# ...
# state                                          LA
# signs_of_mental_illness                     False
# threat_level                               attack
# flee                                         Foot
# body_camera                                 False
# lat                                       32.4659
# lon                                      -93.7959
# Name: 4029, dtype: object
# id                                     4456
# name                            Hunter Alan
# date                             2019-02-06
# manner_of_death            shot and Tasered
# armed                                 knife
# age                                      48
# gender                                    M
# race                                    NaN
# city                               Edinburg
# state                                    TX
# signs_of_mental_illness                True
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                  26.319
# lon                                -98.1607
# Name: 4031, dtype: object
# id                                4446
# name                             TK TK
# date                        2019-02-07
# manner_of_death                   shot
# armed                            knife
# age                                NaN
# gender                               M
# race                               NaN
# city                           Seattle
# state                               WA
# signs_of_mental_illness          False
# threat_level                    attack
# flee                       Not fleeing
# body_camera                       True
# lat                            47.6211
# lon                           -122.324
# Name: 4032, dtype: object
# id                                         4448
# name                       Michael Robert Novak
# date                                 2019-02-07
# manner_of_death                            shot
# armed                                     knife
# age                                          58
# gender                                        M
# race                                        NaN
# city                                     Madera
# state                                        CA
# signs_of_mental_illness                    True
# threat_level                             attack
# flee                                Not fleeing
# body_camera                                True
# lat                                      36.964
# lon                                     -120.08
# Name: 4033, dtype: object
# id                                      4449
# name                       Morgan Shane West
# date                              2019-02-07
# manner_of_death                         shot
# armed                           undetermined
# age                                       38
# gender                                     M
# race                                     NaN
# city                                  Snyder
# state                                     TX
# signs_of_mental_illness                False
# threat_level                    undetermined
# flee                             Not fleeing
# body_camera                            False
# lat                                  32.7133
# lon                                 -100.911
# Name: 4034, dtype: object
# id                                  4450
# name                       Nolan Hurtzig
# date                          2019-02-07
# manner_of_death                     shot
# armed                       undetermined
# age                                   29
# gender                                 M
# race                                 NaN
# city                             Banning
# state                                 CA
# signs_of_mental_illness            False
# threat_level                undetermined
# flee                                 NaN
# body_camera                        False
# lat                               33.946
# lon                             -116.899
# Name: 4035, dtype: object
# id                                       4452
# name                       Jason Matthew Hill
# date                               2019-02-07
# manner_of_death                          shot
# armed                                     gun
# age                                        40
# gender                                      M
# race                                        W
# city                                  Memphis
# state                                      TN
# signs_of_mental_illness                 False
# threat_level                           attack
# flee                              Not fleeing
# body_camera                             False
# lat                                   35.1047
# lon                                  -89.9773
# Name: 4036, dtype: object
# id                                        4451
# name                       Aaron Allen Przkeop
# date                                2019-02-08
# manner_of_death                           shot
# armed                             undetermined
# age                                         25
# gender                                       M
# race                                         W
# city                               Bakersfield
# state                                       CA
# signs_of_mental_illness                  False
# threat_level                             other
# flee                               Not fleeing
# body_camera                              False
# lat                                     35.353
# lon                                   -119.036
# Name: 4037, dtype: object
# id                                           4453
# name                       Joshua Rember Williams
# date                                   2019-02-08
# manner_of_death                              shot
# armed                                       knife
# age                                            32
# gender                                          M
# race                                          NaN
# city                                     New York
# state                                          NY
# signs_of_mental_illness                     False
# threat_level                               attack
# flee                                  Not fleeing
# body_camera                                 False
# lat                                       40.6943
# lon                                      -73.9249
# Name: 4038, dtype: object
# id                                   4441
# name                       Williebo McCoy
# date                           2019-02-09
# manner_of_death                      shot
# armed                                 gun
# age                                   NaN
# gender                                  M
# race                                    B
# city                              Vallejo
# state                                  CA
# signs_of_mental_illness             False
# threat_level                        other
# flee                          Not fleeing
# body_camera                         False
# lat                               38.1133
# lon                              -122.236
# Name: 4039, dtype: object
# id                                     4443
# name                       Jeffrey D. Tyree
# date                             2019-02-09
# manner_of_death                        shot
# armed                                 knife
# age                                      57
# gender                                    M
# race                                      W
# city                         Virginia Beach
# state                                    VA
# signs_of_mental_illness                True
# threat_level                         attack
# flee                            Not fleeing
# body_camera                           False
# lat                                 36.7335
# lon                                -76.0435
# Name: 4040, dtype: object
# id                                     4447
# name                       Jonathan Ramirez
# date                             2019-02-09
# manner_of_death                        shot
# armed                                   gun
# age                                      28
# gender                                    M
# race                                      H
# city                                 Bailey
# state                                    NC
# signs_of_mental_illness               False
# threat_level                          other
# flee                            Not fleeing
# body_camera                            True
# lat                                 35.7806
# lon                                -78.1129
# Name: 4041, dtype: object
# id                                4444
# name                       Ted Schmitz
# date                        2019-02-10
# manner_of_death                   shot
# armed                            knife
# age                                 58
# gender                               M
# race                                 W
# city                          Waukesha
# state                               WI
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# lat                            43.0087
# lon                           -88.2464
# Name: 4042, dtype: object
# id                                 4442
# name                         Eric Young
# date                         2019-02-11
# manner_of_death                    shot
# armed                      undetermined
# age                                  34
# gender                                M
# race                                NaN
# city                         Montgomery
# state                                WV
# signs_of_mental_illness           False
# threat_level               undetermined
# flee                                NaN
# body_camera                       False
# lat                             38.1741
# lon                            -81.3241
# Name: 4044, dtype: object
# id                                   4457
# name                       Ty'rell Pounds
# date                           2019-02-11
# manner_of_death                      shot
# armed                                 gun
# age                                    24
# gender                                  M
# race                                    B
# city                            Crestwood
# state                                  KY
# signs_of_mental_illness             False
# threat_level                       attack
# flee                                  Car
# body_camera                         False
# lat                               38.3355
# lon                              -85.4839
# Name: 4045, dtype: object
# id                                       4461
# name                       Phayvanh Inthavong
# date                               2019-02-11
# manner_of_death                          shot
# armed                                     gun
# age                                        32
# gender                                      M
# race                                        A
# city                                  Redding
# state                                      CA
# signs_of_mental_illness                 False
# threat_level                           attack
# flee                                     Foot
# body_camera                             False
# lat                                   40.5698
# lon                                  -122.365
# Name: 4046, dtype: object
# id                                 4458
# name                       Alex Johnson
# date                         2019-02-12
# manner_of_death                    shot
# armed                             knife
# age                                  58
# gender                                M
# race                                NaN
# city                           Defiance
# state                                OH
# signs_of_mental_illness           False
# threat_level                      other
# flee                        Not fleeing
# body_camera                       False
# lat                              41.281
# lon                             -84.366
# Name: 4047, dtype: object
# id                                4459
# name                             TK TK
# date                        2019-02-12
# manner_of_death                   shot
# armed                              gun
# age                                NaN
# gender                               M
# race                               NaN
# city                       Cinco Ranch
# state                               TX
# signs_of_mental_illness          False
# threat_level                    attack
# flee                              Foot
# body_camera                      False
# lat                            29.7395
# lon                           -95.7607
# Name: 4048, dtype: object
# id                                4460
# name                             TK TK
# date                        2019-02-12
# manner_of_death                   shot
# armed                              gun
# age                                NaN
# gender                               M
# race                               NaN
# city                       Cinco Ranch
# state                               TX
# signs_of_mental_illness          False
# threat_level                    attack
# flee                              Foot
# body_camera                      False
# lat                            29.7395
# lon                           -95.7607
# Name: 4049, dtype: object
# id                                  4464
# name                       Johnny Mathis
# date                          2019-02-12
# manner_of_death                     shot
# armed                       undetermined
# age                                   46
# gender                                 M
# race                                 NaN
# city                              Fresno
# state                                 CA
# signs_of_mental_illness            False
# threat_level                undetermined
# flee                         Not fleeing
# body_camera                        False
# lat                              36.7834
# lon                             -119.794
# Name: 4050, dtype: object
# id                                   4465
# name                       Garrett Ebenal
# date                           2019-02-13
# manner_of_death                      shot
# armed                                 gun
# age                                    28
# gender                                  M
# race                                  NaN
# city                            Fairbanks
# state                                  AK
# signs_of_mental_illness             False
# threat_level                       attack
# flee                          Not fleeing
# body_camera                         False
# lat                               64.8353
# lon                              -147.653
# Name: 4051, dtype: object
# id                                 4462
# name                              TK TK
# date                         2019-02-14
# manner_of_death                    shot
# armed                      undetermined
# age                                 NaN
# gender                              NaN
# race                                NaN
# city                        Los Angeles
# state                                CA
# signs_of_mental_illness           False
# threat_level               undetermined
# flee                        Not fleeing
# body_camera                       False
# lat                             34.1139
# lon                            -118.407
# Name: 4052, dtype: object
# id                                   4463
# name                       Michael Drayer
# date                           2019-02-14
# manner_of_death                      shot
# armed                        undetermined
# age                                    34
# gender                                  M
# race                                  NaN
# city                               Aspers
# state                                  PA
# signs_of_mental_illness             False
# threat_level                       attack
# flee                          Not fleeing
# body_camera                         False
# lat                               39.9765
# lon                               -77.226
# Name: 4053, dtype: object

# %%
a.head(300)
# Out:
#      Unnamed: 0  Unnamed: 0.1   id                              name  \
# 0             0             0    3                        Tim Elliot
# 1             1             1    4                  Lewis Lee Lembke
# 2             2             2    5                John Paul Quintero
# 3             3             3    8                   Matthew Hoffman
# 4             4             4    9                 Michael Rodriguez
# 5             5             5   11                 Kenneth Joe Brown
# 6             6             6   13               Kenneth Arnold Buck
# 7             7             7   15                     Brock Nichols
# 8             8             8   16                     Autumn Steele
# 9             9             9   17                   Leslie Sapp III
# 10           10            10   19                    Patrick Wetter
# 11           11            11   21                         Ron Sneed
# 12           12            12   22    Hashim Hanif Ibn Abdul-Rasheed
# 13           13            13   25            Nicholas Ryan Brickman
# 14           14            14   27  Omarr Julian Maximillian Jackson
# 15           15            15   29                     Loren Simpson
# 16           16            16   32               James Dudley Barker
# 17           17            17   36               Artago Damon Howard
# 18           18            18   37                      Thomas Hamby
# 19           19            19   38                     Jimmy Foreman
# 20           20            20  325                     Andy Martinez
# 21           21            21   42                       Tommy Smith
# 22           22            22   43                    Brian  Barbosa
# 23           23            23   45                 Salvador Figueroa
# 24           24            24   46               John Edward O'Keefe
# 25           25            25   48                 Richard McClendon
# 26           26            26   49                     Marcus Golden
# 27           27            27   50                    Michael Goebel
# 28           28            28   51                      Mario Jordan
# 29           29            29   52                  Talbot Schroeder
# ..          ...           ...  ...                               ...
# 270         270           270  343                   Phillip Burgess
# 271         271           271  335            Angel Cresencio Corona
# 272         272           272  377                      Richard Reed
# 273         273           273  358                      Donald Allen
# 274         274           274  355                         Mack Long
# 275         275           275  357               Richard Dale Weaver
# 276         276           276  362                   Jason Lee Evans
# 277         277           277  356                     Isaac Jimenez
# 278         278           278  363                    Colby Robinson
# 279         279           279  364          Christopher Grant Finley
# 280         280           280  365                     Tevin Barkley
# 281         281           281  366                       Dante Noble
# 282         282           282  367                    Frank Shephard
# 283         283           283  368                     Mark W. Adair
# 284         284           284  369                    Stanley Watson
# 285         285           285  374                    Ernesto Flores
# 286         286           286  373                 Rodolfo Velazquez
# 287         287           287  380                      Jeffrey Kemp
# 288         288           288  381                     Elias Cavazos
# 289         289           289  382                Thaddeus McCarroll
# 290         290           290  376                       Erik Tellez
# 291         291           291  379                       Grover Sapp
# 292         292           292  378                    Michael Foster
# 293         293           293  383                     Dana Hlavinka
# 294         294           294  399           Santos Cortez Hernandez
# 295         295           295  537                      Daniel Wolfe
# 296         296           296  393                Daniel Covarrubias
# 297         297           297  398                        Kimber Key
# 298         298           298  495                     Luis Martinez
# 299         299           299  391                   William Chapman
#
#            date   manner_of_death         armed   age gender race  \
# 0    2015-01-02              shot           gun  53.0      M    A
# 1    2015-01-02              shot           gun  47.0      M    W
# 2    2015-01-03  shot and Tasered       unarmed  23.0      M    H
# 3    2015-01-04              shot    toy weapon  32.0      M    W
# 4    2015-01-04              shot      nail gun  39.0      M    H
# 5    2015-01-04              shot           gun  18.0      M    W
# 6    2015-01-05              shot           gun  22.0      M    H
# 7    2015-01-06              shot           gun  35.0      M    W
# 8    2015-01-06              shot       unarmed  34.0      F    W
# 9    2015-01-06              shot    toy weapon  47.0      M    B
# 10   2015-01-06  shot and Tasered         knife  25.0      M    W
# 11   2015-01-07              shot           gun  31.0      M    B
# 12   2015-01-07              shot         knife  41.0      M    B
# 13   2015-01-07              shot           gun  30.0      M    W
# 14   2015-01-07              shot           gun  37.0      M    B
# 15   2015-01-08              shot           NaN  28.0      M    W
# 16   2015-01-08              shot        shovel  42.0      M    W
# 17   2015-01-08              shot       unarmed  36.0      M    B
# 18   2015-01-08              shot           gun  49.0      M    W
# 19   2015-01-09              shot           gun  71.0      M    W
# 20   2015-01-09              shot           gun  33.0      M    H
# 21   2015-01-11              shot           gun  39.0      M    W
# 22   2015-01-11              shot           gun  23.0      M    H
# 23   2015-01-11  shot and Tasered           gun  29.0      M    H
# 24   2015-01-13              shot           gun  34.0      M    W
# 25   2015-01-13              shot         knife  43.0      M    W
# 26   2015-01-14              shot           NaN  24.0      M    B
# 27   2015-01-14              shot           NaN  29.0      M    W
# 28   2015-01-14              shot           gun  34.0      M    B
# 29   2015-01-14              shot         knife  75.0      M    W
# ..          ...               ...           ...   ...    ...  ...
# 270  2015-04-09              shot           gun  28.0      M    W
# 271  2015-04-10              shot         knife  21.0      M    H
# 272  2015-04-10              shot           gun  38.0      M    W
# 273  2015-04-11              shot           gun  66.0      M    W
# 274  2015-04-12              shot           gun  36.0      M    B
# 275  2015-04-12              shot       machete  83.0      M    W
# 276  2015-04-12              shot           gun  32.0      M    W
# 277  2015-04-13              shot           gun  27.0      M    H
# 278  2015-04-14              shot  undetermined  26.0      M    B
# 279  2015-04-14              shot       machete  31.0      M    W
# 280  2015-04-15              shot           gun  22.0      M    B
# 281  2015-04-15              shot         knife  41.0      M    B
# 282  2015-04-15              shot       unarmed  41.0      M    B
# 283  2015-04-15              shot    toy weapon  51.0      M    W
# 284  2015-04-15              shot           gun  72.0      M    W
# 285  2015-04-15              shot    toy weapon  52.0      M    H
# 286  2015-04-16              shot         knife  47.0      M    H
# 287  2015-04-17              shot           gun  18.0      M    B
# 288  2015-04-17              shot           gun  29.0      M    H
# 289  2015-04-17              shot         knife  23.0      M    B
# 290  2015-04-18              shot           gun  43.0      M    H
# 291  2015-04-18              shot           gun  45.0      M    W
# 292  2015-04-19              shot           gun  40.0      M    W
# 293  2015-04-19              shot         knife  44.0      M    W
# 294  2015-04-20              shot           gun  25.0      M    H
# 295  2015-04-21              shot           NaN  35.0      M    B
# 296  2015-04-21              shot       unarmed  37.0      M    N
# 297  2015-04-21              shot         knife  59.0      M    W
# 298  2015-04-21              shot         knife  35.0      M    H
# 299  2015-04-22              shot       unarmed  18.0      M    B
#
#                 city state  signs_of_mental_illness  threat_level  \
# 0            Shelton    WA                     True        attack
# 1              Aloha    OR                    False        attack
# 2            Wichita    KS                    False         other
# 3      San Francisco    CA                     True        attack
# 4              Evans    CO                    False        attack
# 5            Guthrie    OK                    False        attack
# 6           Chandler    AZ                    False        attack
# 7            Assaria    KS                    False        attack
# 8         Burlington    IA                    False         other
# 9          Knoxville    PA                    False        attack
# 10          Stockton    CA                    False        attack
# 11          Freeport    TX                    False        attack
# 12          Columbus    OH                     True         other
# 13        Des Moines    IA                    False        attack
# 14       New Orleans    LA                    False        attack
# 15           Huntley    MT                    False  undetermined
# 16    Salt Lake City    UT                    False        attack
# 17            Strong    AR                    False        attack
# 18          Syracuse    UT                    False        attack
# 19           England    AR                    False        attack
# 20           El Paso    TX                    False        attack
# 21            Arcola    IL                     True        attack
# 22        South Gate    CA                    False        attack
# 23   North Las Vegas    NV                    False        attack
# 24       Albuquerque    NM                    False        attack
# 25        Jourdanton    TX                     True         other
# 26          St. Paul    MN                    False        attack
# 27   Franklin County    MO                    False        attack
# 28        Chesapeake    VA                     True        attack
# 29        Old Bridge    NJ                    False        attack
# ..               ...   ...                      ...           ...
# 270  Boiling Springs    SC                    False        attack
# 271          Corning    CA                    False        attack
# 272           Topeka    KS                    False        attack
# 273     Sand Springs    OK                     True        attack
# 274     Indianapolis    IN                    False        attack
# 275    Oklahoma City    OK                     True         other
# 276        Salemburg    NC                     True        attack
# 277            Alton    IL                    False        attack
# 278           DeSoto    TX                    False  undetermined
# 279        Jonesboro    AR                     True        attack
# 280            Miami    FL                    False  undetermined
# 281      Spartanburg    SC                    False        attack
# 282          Houston    TX                    False         other
# 283         Columbia    MO                    False        attack
# 284       Cañon City    CO                     True        attack
# 285        Montclair    CA                     True        attack
# 286          Shafter    CA                    False         other
# 287          Chicago    IL                    False        attack
# 288            Hemet    CA                    False        attack
# 289         Jennings    MO                     True         other
# 290          Phoenix    AZ                     True        attack
# 291      Panama City    FL                    False        attack
# 292          Wilmore    KY                     True        attack
# 293           Sidney    NE                    False        attack
# 294          Mission    TX                    False         other
# 295          Trenton    NJ                    False        attack
# 296         Lakewood    WA                     True         other
# 297             Irmo    SC                     True         other
# 298      Los Angeles    CA                     True         other
# 299       Portsmouth    VA                    False  undetermined
#
#             flee  body_camera      lat
# 0    Not fleeing        False  36.1315
# 1    Not fleeing        False  36.1315
# 2    Not fleeing        False  36.1315
# 3    Not fleeing        False  36.1315
# 4    Not fleeing        False  36.1315
# 5    Not fleeing        False  36.1315
# 6            Car        False  36.1315
# 7    Not fleeing        False  36.1315
# 8    Not fleeing         True  36.1315
# 9    Not fleeing        False  36.1315
# 10   Not fleeing        False  36.1315
# 11   Not fleeing        False  36.1315
# 12   Not fleeing        False  36.1315
# 13           Car        False  36.1315
# 14          Foot         True  36.1315
# 15   Not fleeing        False  36.1315
# 16   Not fleeing         True  36.1315
# 17   Not fleeing        False  36.1315
# 18   Not fleeing         True  36.1315
# 19   Not fleeing        False  36.1315
# 20   Not fleeing        False  36.1315
# 21   Not fleeing        False  36.1315
# 22   Not fleeing        False  36.1315
# 23          Foot        False  36.1315
# 24          Foot         True  36.1315
# 25   Not fleeing        False  36.1315
# 26   Not fleeing        False  36.1315
# 27   Not fleeing        False  36.1315
# 28   Not fleeing        False  36.1315
# 29   Not fleeing        False  36.1315
# ..           ...          ...      ...
# 270  Not fleeing        False  36.1315
# 271  Not fleeing        False  36.1315
# 272          Car        False  36.1315
# 273  Not fleeing         True  36.1315
# 274         Foot         True  36.1315
# 275  Not fleeing        False  36.1315
# 276          Car        False  36.1315
# 277  Not fleeing        False  36.1315
# 278         Foot        False  36.1315
# 279  Not fleeing        False  36.1315
# 280         Foot        False  36.1315
# 281  Not fleeing        False  36.1315
# 282          Car        False  36.1315
# 283          Car         True  36.1315
# 284  Not fleeing        False  36.1315
# 285  Not fleeing        False  36.1315
# 286  Not fleeing        False  36.1315
# 287         Foot        False  36.1315
# 288  Not fleeing        False  36.1315
# 289  Not fleeing         True  36.1315
# 290  Not fleeing        False  36.1315
# 291  Not fleeing        False  36.1315
# 292  Not fleeing        False  36.1315
# 293  Not fleeing        False  36.1315
# 294  Not fleeing        False  36.1315
# 295  Not fleeing        False  36.1315
# 296         Foot        False  36.1315
# 297  Not fleeing        False  36.1315
# 298  Not fleeing        False  36.1315
# 299  Not fleeing        False  36.1315
#
# [300 rows x 17 columns]

# %%
print(b.cities)
